# %% [markdown]
# ## **Crime Rate Prediction using machine learning models.**
#
# For prediction, we will use following algorithms:
#
# Linear Regression
#
# Lasso Regression
#
# Ridge Regression
#
# By using the above algorithms, we will firstly explore the data that we have and check for any null or missing values. If found then we'll clean tha data and then visualize it for better understanding and draw insights.
# Then we'll proceed by data training i.e. spliting data into training and testing data.Then train our model by providing training data and once the model will be trained, we will perform prediction for the test data.
# At last, we will evaluate the performance of these algorithmns by error check and accuracy check.

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/dataset.csv')
data.head()
# Out:
#        States/UTs  Murder  Attempt to commit Murder  \
# 0     A&N Islands       5                        10
# 1     A&N Islands       2                         1
# 2     A&N Islands       1                         0
# 3     A&N Islands       8                        11
# 4  Andhra Pradesh     134                       171
#
#    Culpable Homicide not amounting to Murder  \
# 0                                          2
# 1                                          2
# 2                                          0
# 3                                          4
# 4                                          8
#
#    Attempt to commit Culpable Homicide  Rape  Custodial Rape  \
# 0                                    1    19               0
# 1                                    1    11               0
# 2                                    0     2               0
# 3                                    2    32               0
# 4                                    0    35               0
#
# ...

# %%
data.shape
# Out:
# (838, 89)

# %% [markdown]
# Check for null values:

# %%
data.isnull().sum()
# Out:
# States/UTs                                   0
# Murder                                       0
# Attempt to commit Murder                     0
# Culpable Homicide not amounting to Murder    0
# Attempt to commit Culpable Homicide          0
#                                             ..
# Incidence of Rash Driving                    0
# HumanTrafficking                             0
# Unnatural Offence                            0
# Other IPC crimes                             0
# Total Cognizable IPC crimes                  0
# Length: 89, dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## **Data Preparation & Training**

# %%
data.columns
# Out:
# Index(['States/UTs', 'Murder', 'Attempt to commit Murder',
#        'Culpable Homicide not amounting to Murder',
#        'Attempt to commit Culpable Homicide', 'Rape', 'Custodial Rape',
#        'Custodial_Gang Rape', 'Custodial_Other Rape',
#        'Rape other than Custodial', 'Rape_Gang Rape', 'Rape_Others',
#        'Attempt to commit Rape', 'Kidnapping & Abduction_Total',
#        'Kidnapping & Abduction', 'Kidnapping & Abduction in order to Murder',
#        'Kidnapping for Ransom',
#        'Kidnapping & Abduction of Women to compel her for marriage',
#        'Other Kidnapping', 'Dacoity', 'Dacoity with Murder', 'Other Dacoity',
#        'Making Preparation and Assembly for committing Dacoity', 'Robbery',
#        'Criminal Trespass/Burglary', 'Criminal Trespass or Burglary',
#        'House Trespass & House Breaking', 'Theft', 'Auto Theft',
#        'Other Thefts', 'Unlawful Assembly', 'Riots', 'Riots_Communal',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838 entries, 0 to 837
# Data columns (total 89 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   States/UTs                                                        838 non-null    object
#  1   Murder                                                            838 non-null    int64
#  2   Attempt to commit Murder                                          838 non-null    int64
#  3   Culpable Homicide not amounting to Murder                         838 non-null    int64
#  4   Attempt to commit Culpable Homicide                               838 non-null    int64
#  5   Rape                                                              838 non-null    int64
#  6   Custodial Rape                                                    838 non-null    int64
# ...

# %% [markdown]
# 'States/UTs' column is of object type so we will convert it into integer type using get_dummies function and then proceed with further steps.

# %%
columns=['States/UTs']
data1=data[columns]
dummies=pd.get_dummies(data1,columns=['States/UTs'])
dummies
# Out:
#      States/UTs_A&N Islands  States/UTs_Andhra Pradesh  \
# 0                         1                          0
# 1                         1                          0
# 2                         1                          0
# 3                         1                          0
# 4                         0                          1
# ..                      ...                        ...
# 833                       0                          0
# 834                       0                          0
# 835                       0                          0
# 836                       0                          0
# 837                       0                          0
#
#      States/UTs_Arunachal Pradesh  States/UTs_Assam  States/UTs_Bihar  \
# 0                               0                 0                 0
# 1                               0                 0                 0
# 2                               0                 0                 0
# ...

# %%
#merging the int columns with our original dataset.
mergeddata= pd.concat([data,dummies],axis='columns')
mergeddata
# Out:
#          States/UTs  Murder  Attempt to commit Murder  \
# 0       A&N Islands       5                        10
# 1       A&N Islands       2                         1
# 2       A&N Islands       1                         0
# 3       A&N Islands       8                        11
# 4    Andhra Pradesh     134                       171
# ..              ...     ...                       ...
# 833     West Bengal      23                        11
# 834     West Bengal       8                         2
# 835     West Bengal      46                        49
# 836     West Bengal      90                       346
# 837     West Bengal    2370                      7355
#
#      Culpable Homicide not amounting to Murder  \
# 0                                            2
# 1                                            2
# 2                                            0
# 3                                            4
# 4                                            8
# ...

# %%
#dropping States/UTs column to avoid issues later.
prepareddata=mergeddata.drop(['States/UTs'],axis='columns')
prepareddata
# Out:
#      Murder  Attempt to commit Murder  \
# 0         5                        10
# 1         2                         1
# 2         1                         0
# 3         8                        11
# 4       134                       171
# ..      ...                       ...
# 833      23                        11
# 834       8                         2
# 835      46                        49
# 836      90                       346
# 837    2370                      7355
#
#      Culpable Homicide not amounting to Murder  \
# 0                                            2
# 1                                            2
# 2                                            0
# 3                                            4
# 4                                            8
# ..                                         ...
# 833                                          0
# 834                                          0
# 835                                          7
# ...

# %%
prepareddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838 entries, 0 to 837
# Columns: 124 entries, Murder to States/UTs_West Bengal
# dtypes: int64(88), uint8(36)
# memory usage: 605.7 KB

# %%
prepareddata.columns
# Out:
# Index(['Murder', 'Attempt to commit Murder',
#        'Culpable Homicide not amounting to Murder',
#        'Attempt to commit Culpable Homicide', 'Rape', 'Custodial Rape',
#        'Custodial_Gang Rape', 'Custodial_Other Rape',
#        'Rape other than Custodial', 'Rape_Gang Rape',
#        ...
#        'States/UTs_Puducherry', 'States/UTs_Punjab', 'States/UTs_Rajasthan',
#        'States/UTs_Sikkim', 'States/UTs_Tamil Nadu', 'States/UTs_Telangana',
#        'States/UTs_Tripura', 'States/UTs_Uttar Pradesh',
#        'States/UTs_Uttarakhand', 'States/UTs_West Bengal'],
#       dtype='object', length=124)

# %% [markdown]
# ### **Data Training**

# %%
# Import train_test_split from sklearn.model_selection
from sklearn.model_selection import train_test_split
# Here, X is the data which will have feature and y will have our target.
x=prepareddata.drop(['Total Cognizable IPC crimes'],axis='columns') 
y=prepareddata['Total Cognizable IPC crimes']

# %%
# Split data into training data and testing data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3,random_state=100) 
#Ratio used for splitting training and testing data is 7:3 respectively

# %% [markdown]
# ## **Model Creation**

# %% [markdown]
# Linear Regression

# %%
# Importing linear regression model
from sklearn.linear_model import LinearRegression 
reg1 = LinearRegression()

# %%
# Fitting data into the model.
reg1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Making predictions 
pred1 = reg1.predict(x_test)

# %%
pred1
# Out:
# array([7.91000610e+03, 1.09952857e+01, 8.10000000e+01, 1.13200333e+03,
#        9.48999005e+03, 4.59989084e+02, 2.43101277e+03, 9.87985141e+02,
#        3.75199683e+03, 4.87001769e+03, 3.99998159e+02, 8.03000556e+02,
#        1.02600517e+03, 1.59200498e+03, 3.61400780e+03, 6.70990553e+02,
#        4.03605942e+04, 8.01000025e+02, 5.63998740e+03, 3.88998602e+02,
#        7.92992309e+02, 6.71599593e+03, 2.89601134e+03, 2.33996966e+02,
#        5.95998809e+02, 1.35699058e+03, 2.80698444e+03, 9.86014295e+02,
#        1.94500100e+03, 1.22299827e+03, 2.70200450e+03, 9.01012867e+00,
#        1.60699849e+03, 2.47096835e+03, 1.57999412e+03, 1.67026442e+02,
#        2.03877886e-02, 2.93100979e+03, 7.99993718e+01, 2.69799303e+03,
#        6.73997927e+02, 1.94798885e+03, 2.95001182e+03, 4.61200951e+03,
#        9.86800574e+03, 9.19997557e+02, 1.25019305e+02, 3.77701848e+03,
#        2.34200296e+03, 6.00900950e+03, 3.01394696e+03, 1.18500317e+03,
# ...

# %%
print("Accuracy of the Linear Regression model is: \n ") 
print(reg1.score(x_train,y_train))
# Out:
# Accuracy of the Linear Regression model is:
#
# 0.9999999999967659

# %% [markdown]
# **Lasso Regression**

# %%
# Importing model
from sklearn.linear_model import Lasso
reg2 = Lasso()

# %%
# Fitting data into the model.
reg2.fit(x_train, y_train)
# Out:
# Lasso()

# %%
# Making predictions 
pred2 = reg2.predict(x_test)

# %%
pred2
# Out:
# array([ 7.65175858e+03, -1.66282414e+02,  2.02557052e+02,  1.35930820e+03,
#         9.93009388e+03,  5.50621793e+02,  2.18363120e+03,  1.02076431e+03,
#         3.80910832e+03,  4.42900577e+03,  3.72573184e+02,  7.88285652e+02,
#         1.22284638e+03,  1.52617466e+03,  3.47232918e+03,  6.40248688e+02,
#         4.03657230e+04,  8.82779546e+02,  6.09209817e+03,  3.86197991e+02,
#         8.10416673e+02,  9.19034040e+03,  2.90079446e+03,  2.60671317e+02,
#         3.69046779e+02,  1.19555890e+03,  2.94222186e+03,  9.94663725e+02,
#         1.90824007e+03,  1.63761301e+03,  2.56294225e+03, -7.45344879e+00,
#         1.53420662e+03,  2.14967485e+03,  9.91320306e+02,  2.19079694e+00,
#         2.27820382e+00,  2.84568429e+03,  1.21726119e+02,  2.64063176e+03,
#         4.02348627e+02,  2.37813057e+03,  2.27432248e+03,  4.26538821e+03,
#         1.00104228e+04,  1.02680479e+03,  1.82923765e+02,  3.81949569e+03,
# ...

# %%
print("Accuracy of the Lasso Regression model is: \n ") 
print(reg2.score(x_train,y_train))
# Out:
# Accuracy of the Lasso Regression model is:
#
# 0.9999060571652227

# %% [markdown]
# Ridge Regression

# %%
# Importing model
from sklearn.linear_model import Ridge
reg3 = Ridge()

# %%
# Fitting data into the model.
reg3.fit(x_train, y_train)
# Out:
# Ridge()

# %%
# Making predictions 
pred3 = reg3.predict(x_test)

# %%
pred3
# Out:
# array([7.91000018e+03, 1.09857063e+01, 8.10000788e+01, 1.13200400e+03,
#        9.49001908e+03, 4.59991742e+02, 2.43101040e+03, 9.87987778e+02,
#        3.75199581e+03, 4.87001228e+03, 3.99997280e+02, 8.02989222e+02,
#        1.02600992e+03, 1.59201816e+03, 3.61400256e+03, 6.71002778e+02,
#        4.03606045e+04, 8.00994836e+02, 5.64000464e+03, 3.89000013e+02,
#        7.92994434e+02, 6.71603501e+03, 2.89600903e+03, 2.33995657e+02,
#        5.95990463e+02, 1.35698901e+03, 2.80698400e+03, 9.86016724e+02,
#        1.94500029e+03, 1.22299432e+03, 2.70200364e+03, 9.00901311e+00,
#        1.60699913e+03, 2.47096518e+03, 1.57998473e+03, 1.67021067e+02,
#        1.78982912e-02, 2.93101880e+03, 7.99994066e+01, 2.69799270e+03,
#        6.73994693e+02, 1.94799497e+03, 2.94996469e+03, 4.61200720e+03,
#        9.86801624e+03, 9.19998784e+02, 1.25015250e+02, 3.77700328e+03,
#        2.34200381e+03, 6.00900427e+03, 3.01392133e+03, 1.18500074e+03,
# ...

# %%
print("Accuracy of the Ridge Regression model is: \n ") 
print(reg3.score(x_train,y_train))
# Out:
# Accuracy of the Ridge Regression model is:
#
# 0.9999999999963987

# %% [markdown]
# Perfromance Evaluation

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
print("Model\t\t\t          RootMeanSquareError  \t\t    Accuracy of the model") 
print("""Linear Regression       \t\t {:.4f} \t \t\t {:.4f}""".format(  np.sqrt(mean_squared_error(y_test, pred1)), reg1.score(x_train,y_train)))
print("""Lasso Regression        \t\t {:.4f} \t \t\t {:.4f}""".format(  np.sqrt(mean_squared_error(y_test, pred2)), reg2.score(x_train,y_train)))
print("""Ridge Regression        \t\t {:.4f} \t \t\t {:.4f}""".format(  np.sqrt(mean_squared_error(y_test, pred3)), reg3.score(x_train,y_train)))
# Out:
# Model			          RootMeanSquareError  		    Accuracy of the model
# Linear Regression       		 0.1522 	 		 1.0000
# Lasso Regression        		 1164.1556 	 		 0.9999
# Ridge Regression        		 0.1692 	 		 1.0000
